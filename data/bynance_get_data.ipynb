# %%
import os
from binance.client import Client
client = Client(api_key, api_secret)
client._get_earliest_valid_timestamp('BTCUSDT', '1m')

from datetime import datetime
import pandas as pd
import requests
from typing import *
import time

class BinanceClient:
    def __init__(self, futures=False):
        self.exchange = "BINANCE"
        self.futures = futures

        if self.futures:
            self._base_url = "https://fapi.binance.com"
        else:
            self._base_url = "https://api.binance.com"

        self.symbols = self._get_symbols()

    def _make_request(self, endpoint: str, query_parameters: Dict):
        try:
            response = requests.get(self._base_url + endpoint, params=query_parameters)
        except Exception as e:
            print("Connection error while making request to %s: %s", endpoint, e)
            return None

        if response.status_code == 200:
            return response.json()
        else:
            print("Error while making request to %s: %s (status code = %s)",
                         endpoint, response.json(), response.status_code)
            return None

    def _get_symbols(self) -> List[str]:

        params = dict()

        endpoint = "/fapi/v1/exchangeInfo" if self.futures else "/api/v3/exchangeInfo"
        data = self._make_request(endpoint, params)

        symbols = [x["symbol"] for x in data["symbols"]]

        return symbols

    def get_historical_data(self, symbol: str, interval: Optional[str] = "1m", start_time: Optional[int] = None, end_time: Optional[int] = None, limit: Optional[int] = 1500):

        params = dict()

        params["symbol"] = symbol
        params["interval"] = interval
        params["limit"] = limit

        if start_time is not None:
            params["startTime"] = start_time
        if end_time is not None:
            params["endTime"] = end_time

        endpoint = "/fapi/v1/klines" if self.futures else "/api/v3/klines"
        raw_candles = self._make_request(endpoint, params)

        candles = []

        if raw_candles is not None:
            for c in raw_candles:
                candles.append((float(c[0]), float(c[1]), float(c[2]), float(c[3]), float(c[4]), float(c[5]),))
            return candles
        else:
            return None

def ms_to_dt_utc(ms: int) -> datetime:
    return datetime.utcfromtimestamp(ms / 1000)

def ms_to_dt_local(ms: int) -> datetime:
    return datetime.fromtimestamp(ms / 1000)

def GetDataFrame(data):
    df = pd.DataFrame(data, columns=['Timestamp', "Open", "High", "Low", "Close", "Volume"])
    df["Timestamp"] = df["Timestamp"].apply(lambda x: ms_to_dt_local(x))
    df['Date'] = df["Timestamp"].dt.strftime("%d/%m/%Y")
    df['Time'] = df["Timestamp"].dt.strftime("%H:%M:%S")
    column_names = ["Date", "Time", "Open", "High", "Low", "Close", "Volume"]
    df = df.set_index('Timestamp')
    df = df.reindex(columns=column_names)

    return df

def GetHistoricalData(client, symbol, start_time, end_time, limit=1500):
    collection = []

    while start_time < end_time:
        data = client.get_historical_data(symbol, start_time=start_time, end_time=end_time, limit=limit)
        print(client.exchange + " " + symbol + " : Collected " + str(len(data)) + " initial data from "+ str(ms_to_dt_local(data[0][0])) +" to " + str(ms_to_dt_local(data[-1][0])))
        start_time = int(data[-1][0] + 1000)
        collection +=data
        time.sleep(1.1)

    return collection
    
client = BinanceClient(futures=False)
symbol = "BTCUSDT"
interval = "1h"
fromDate = int(datetime.strptime('2022-01-23', '%Y-%m-%d').timestamp() * 1000)
toDate = int(datetime.strptime('2022-01-25', '%Y-%m-%d').timestamp() * 1000)

data = GetHistoricalData(client, symbol, fromDate, toDate)
df = GetDataFrame(data)
#df.to_csv('btc_1h_data.csv')
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-23 00:00:00 to 2022-01-23 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-23 16:40:00 to 2022-01-24 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-24 09:20:00 to 2022-01-25 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-25 02:00:00 to 2022-01-25 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-25 18:40:00 to 2022-01-26 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-26 11:20:00 to 2022-01-27 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-27 04:00:00 to 2022-01-27 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-27 20:40:00 to 2022-01-28 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-28 13:20:00 to 2022-01-29 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-29 06:00:00 to 2022-01-29 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-29 22:40:00 to 2022-01-30 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-30 15:20:00 to 2022-01-31 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-01-31 08:00:00 to 2022-02-01 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-01 00:40:00 to 2022-02-01 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-01 17:20:00 to 2022-02-02 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-02 10:00:00 to 2022-02-03 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-03 02:40:00 to 2022-02-03 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-03 19:20:00 to 2022-02-04 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-04 12:00:00 to 2022-02-05 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-05 04:40:00 to 2022-02-05 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-05 21:20:00 to 2022-02-06 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-06 14:00:00 to 2022-02-07 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-07 06:40:00 to 2022-02-07 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-07 23:20:00 to 2022-02-08 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-08 16:00:00 to 2022-02-09 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-09 08:40:00 to 2022-02-10 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-10 01:20:00 to 2022-02-10 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-10 18:00:00 to 2022-02-11 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-11 10:40:00 to 2022-02-12 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-12 03:20:00 to 2022-02-12 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-12 20:00:00 to 2022-02-13 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-13 12:40:00 to 2022-02-14 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-14 05:20:00 to 2022-02-14 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-14 22:00:00 to 2022-02-15 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-15 14:40:00 to 2022-02-16 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-16 07:20:00 to 2022-02-16 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-17 00:00:00 to 2022-02-17 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-17 16:40:00 to 2022-02-18 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-18 09:20:00 to 2022-02-19 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-19 02:00:00 to 2022-02-19 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-19 18:40:00 to 2022-02-20 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-20 11:20:00 to 2022-02-21 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-21 04:00:00 to 2022-02-21 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-21 20:40:00 to 2022-02-22 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-22 13:20:00 to 2022-02-23 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-23 06:00:00 to 2022-02-23 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-23 22:40:00 to 2022-02-24 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-24 15:20:00 to 2022-02-25 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-25 08:00:00 to 2022-02-26 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-26 00:40:00 to 2022-02-26 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-26 17:20:00 to 2022-02-27 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-27 10:00:00 to 2022-02-28 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-28 02:40:00 to 2022-02-28 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-02-28 19:20:00 to 2022-03-01 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-01 12:00:00 to 2022-03-02 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-02 04:40:00 to 2022-03-02 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-02 21:20:00 to 2022-03-03 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-03 14:00:00 to 2022-03-04 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-04 06:40:00 to 2022-03-04 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-04 23:20:00 to 2022-03-05 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-05 16:00:00 to 2022-03-06 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-06 08:40:00 to 2022-03-07 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-07 01:20:00 to 2022-03-07 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-07 18:00:00 to 2022-03-08 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-08 10:40:00 to 2022-03-09 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-09 03:20:00 to 2022-03-09 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-09 20:00:00 to 2022-03-10 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-10 12:40:00 to 2022-03-11 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-11 05:20:00 to 2022-03-11 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-11 22:00:00 to 2022-03-12 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-12 14:40:00 to 2022-03-13 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-13 07:20:00 to 2022-03-13 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-14 00:00:00 to 2022-03-14 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-14 16:40:00 to 2022-03-15 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-15 09:20:00 to 2022-03-16 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-16 02:00:00 to 2022-03-16 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-16 18:40:00 to 2022-03-17 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-17 11:20:00 to 2022-03-18 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-18 04:00:00 to 2022-03-18 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-18 20:40:00 to 2022-03-19 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-19 13:20:00 to 2022-03-20 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-20 06:00:00 to 2022-03-20 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-20 22:40:00 to 2022-03-21 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-21 15:20:00 to 2022-03-22 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-22 08:00:00 to 2022-03-23 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-23 00:40:00 to 2022-03-23 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-23 17:20:00 to 2022-03-24 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-24 10:00:00 to 2022-03-25 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-25 02:40:00 to 2022-03-25 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-25 19:20:00 to 2022-03-26 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-26 12:00:00 to 2022-03-27 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-27 04:40:00 to 2022-03-27 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-27 21:20:00 to 2022-03-28 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-28 14:00:00 to 2022-03-29 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-29 06:40:00 to 2022-03-29 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-29 23:20:00 to 2022-03-30 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-30 16:00:00 to 2022-03-31 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-03-31 08:40:00 to 2022-04-01 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-01 01:20:00 to 2022-04-01 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-01 18:00:00 to 2022-04-02 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-02 10:40:00 to 2022-04-03 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-03 03:20:00 to 2022-04-03 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-03 20:00:00 to 2022-04-04 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-04 12:40:00 to 2022-04-05 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-05 05:20:00 to 2022-04-05 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-05 22:00:00 to 2022-04-06 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-06 14:40:00 to 2022-04-07 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-07 07:20:00 to 2022-04-07 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-08 00:00:00 to 2022-04-08 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-08 16:40:00 to 2022-04-09 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-09 09:20:00 to 2022-04-10 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-10 02:00:00 to 2022-04-10 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-10 18:40:00 to 2022-04-11 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-11 11:20:00 to 2022-04-12 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-12 04:00:00 to 2022-04-12 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-12 20:40:00 to 2022-04-13 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-13 13:20:00 to 2022-04-14 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-14 06:00:00 to 2022-04-14 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-14 22:40:00 to 2022-04-15 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-15 15:20:00 to 2022-04-16 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-16 08:00:00 to 2022-04-17 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-17 00:40:00 to 2022-04-17 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-17 17:20:00 to 2022-04-18 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-18 10:00:00 to 2022-04-19 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-19 02:40:00 to 2022-04-19 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-19 19:20:00 to 2022-04-20 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-20 12:00:00 to 2022-04-21 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-21 04:40:00 to 2022-04-21 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-21 21:20:00 to 2022-04-22 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-22 14:00:00 to 2022-04-23 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-23 06:40:00 to 2022-04-23 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-23 23:20:00 to 2022-04-24 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-24 16:00:00 to 2022-04-25 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-25 08:40:00 to 2022-04-26 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-26 01:20:00 to 2022-04-26 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-26 18:00:00 to 2022-04-27 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-27 10:40:00 to 2022-04-28 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-28 03:20:00 to 2022-04-28 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-28 20:00:00 to 2022-04-29 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-29 12:40:00 to 2022-04-30 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-30 05:20:00 to 2022-04-30 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-04-30 22:00:00 to 2022-05-01 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-01 14:40:00 to 2022-05-02 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-02 07:20:00 to 2022-05-02 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-03 00:00:00 to 2022-05-03 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-03 16:40:00 to 2022-05-04 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-04 09:20:00 to 2022-05-05 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-05 02:00:00 to 2022-05-05 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-05 18:40:00 to 2022-05-06 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-06 11:20:00 to 2022-05-07 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-07 04:00:00 to 2022-05-07 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-07 20:40:00 to 2022-05-08 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-08 13:20:00 to 2022-05-09 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-09 06:00:00 to 2022-05-09 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-09 22:40:00 to 2022-05-10 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-10 15:20:00 to 2022-05-11 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-11 08:00:00 to 2022-05-12 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-12 00:40:00 to 2022-05-12 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-12 17:20:00 to 2022-05-13 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-13 10:00:00 to 2022-05-14 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-14 02:40:00 to 2022-05-14 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-14 19:20:00 to 2022-05-15 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-15 12:00:00 to 2022-05-16 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-16 04:40:00 to 2022-05-16 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-16 21:20:00 to 2022-05-17 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-17 14:00:00 to 2022-05-18 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-18 06:40:00 to 2022-05-18 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-18 23:20:00 to 2022-05-19 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-19 16:00:00 to 2022-05-20 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-20 08:40:00 to 2022-05-21 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-21 01:20:00 to 2022-05-21 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-21 18:00:00 to 2022-05-22 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-22 10:40:00 to 2022-05-23 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-23 03:20:00 to 2022-05-23 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-23 20:00:00 to 2022-05-24 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-24 12:40:00 to 2022-05-25 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-25 05:20:00 to 2022-05-25 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-25 22:00:00 to 2022-05-26 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-26 14:40:00 to 2022-05-27 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-27 07:20:00 to 2022-05-27 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-28 00:00:00 to 2022-05-28 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-28 16:40:00 to 2022-05-29 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-29 09:20:00 to 2022-05-30 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-30 02:00:00 to 2022-05-30 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-30 18:40:00 to 2022-05-31 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-05-31 11:20:00 to 2022-06-01 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-01 04:00:00 to 2022-06-01 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-01 20:40:00 to 2022-06-02 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-02 13:20:00 to 2022-06-03 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-03 06:00:00 to 2022-06-03 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-03 22:40:00 to 2022-06-04 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-04 15:20:00 to 2022-06-05 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-05 08:00:00 to 2022-06-06 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-06 00:40:00 to 2022-06-06 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-06 17:20:00 to 2022-06-07 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-07 10:00:00 to 2022-06-08 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-08 02:40:00 to 2022-06-08 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-08 19:20:00 to 2022-06-09 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-09 12:00:00 to 2022-06-10 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-10 04:40:00 to 2022-06-10 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-10 21:20:00 to 2022-06-11 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-11 14:00:00 to 2022-06-12 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-12 06:40:00 to 2022-06-12 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-12 23:20:00 to 2022-06-13 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-13 16:00:00 to 2022-06-14 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-14 08:40:00 to 2022-06-15 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-15 01:20:00 to 2022-06-15 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-15 18:00:00 to 2022-06-16 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-16 10:40:00 to 2022-06-17 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-17 03:20:00 to 2022-06-17 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-17 20:00:00 to 2022-06-18 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-18 12:40:00 to 2022-06-19 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-19 05:20:00 to 2022-06-19 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-19 22:00:00 to 2022-06-20 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-20 14:40:00 to 2022-06-21 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-21 07:20:00 to 2022-06-21 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-22 00:00:00 to 2022-06-22 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-22 16:40:00 to 2022-06-23 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-23 09:20:00 to 2022-06-24 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-24 02:00:00 to 2022-06-24 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-24 18:40:00 to 2022-06-25 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-25 11:20:00 to 2022-06-26 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-26 04:00:00 to 2022-06-26 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-26 20:40:00 to 2022-06-27 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-27 13:20:00 to 2022-06-28 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-28 06:00:00 to 2022-06-28 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-28 22:40:00 to 2022-06-29 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-29 15:20:00 to 2022-06-30 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-06-30 08:00:00 to 2022-07-01 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-01 00:40:00 to 2022-07-01 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-01 17:20:00 to 2022-07-02 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-02 10:00:00 to 2022-07-03 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-03 02:40:00 to 2022-07-03 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-03 19:20:00 to 2022-07-04 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-04 12:00:00 to 2022-07-05 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-05 04:40:00 to 2022-07-05 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-05 21:20:00 to 2022-07-06 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-06 14:00:00 to 2022-07-07 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-07 06:40:00 to 2022-07-07 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-07 23:20:00 to 2022-07-08 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-08 16:00:00 to 2022-07-09 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-09 08:40:00 to 2022-07-10 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-10 01:20:00 to 2022-07-10 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-10 18:00:00 to 2022-07-11 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-11 10:40:00 to 2022-07-12 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-12 03:20:00 to 2022-07-12 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-12 20:00:00 to 2022-07-13 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-13 12:40:00 to 2022-07-14 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-14 05:20:00 to 2022-07-14 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-14 22:00:00 to 2022-07-15 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-15 14:40:00 to 2022-07-16 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-16 07:20:00 to 2022-07-16 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-17 00:00:00 to 2022-07-17 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-17 16:40:00 to 2022-07-18 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-18 09:20:00 to 2022-07-19 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-19 02:00:00 to 2022-07-19 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-19 18:40:00 to 2022-07-20 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-20 11:20:00 to 2022-07-21 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-21 04:00:00 to 2022-07-21 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-21 20:40:00 to 2022-07-22 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-22 13:20:00 to 2022-07-23 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-23 06:00:00 to 2022-07-23 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-23 22:40:00 to 2022-07-24 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-24 15:20:00 to 2022-07-25 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-25 08:00:00 to 2022-07-26 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-26 00:40:00 to 2022-07-26 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-26 17:20:00 to 2022-07-27 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-27 10:00:00 to 2022-07-28 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-28 02:40:00 to 2022-07-28 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-28 19:20:00 to 2022-07-29 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-29 12:00:00 to 2022-07-30 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-30 04:40:00 to 2022-07-30 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-30 21:20:00 to 2022-07-31 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-07-31 14:00:00 to 2022-08-01 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-01 06:40:00 to 2022-08-01 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-01 23:20:00 to 2022-08-02 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-02 16:00:00 to 2022-08-03 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-03 08:40:00 to 2022-08-04 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-04 01:20:00 to 2022-08-04 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-04 18:00:00 to 2022-08-05 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-05 10:40:00 to 2022-08-06 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-06 03:20:00 to 2022-08-06 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-06 20:00:00 to 2022-08-07 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-07 12:40:00 to 2022-08-08 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-08 05:20:00 to 2022-08-08 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-08 22:00:00 to 2022-08-09 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-09 14:40:00 to 2022-08-10 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-10 07:20:00 to 2022-08-10 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-11 00:00:00 to 2022-08-11 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-11 16:40:00 to 2022-08-12 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-12 09:20:00 to 2022-08-13 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-13 02:00:00 to 2022-08-13 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-13 18:40:00 to 2022-08-14 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-14 11:20:00 to 2022-08-15 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-15 04:00:00 to 2022-08-15 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-15 20:40:00 to 2022-08-16 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-16 13:20:00 to 2022-08-17 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-17 06:00:00 to 2022-08-17 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-17 22:40:00 to 2022-08-18 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-18 15:20:00 to 2022-08-19 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-19 08:00:00 to 2022-08-20 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-20 00:40:00 to 2022-08-20 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-20 17:20:00 to 2022-08-21 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-21 10:00:00 to 2022-08-22 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-22 02:40:00 to 2022-08-22 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-22 19:20:00 to 2022-08-23 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-23 12:00:00 to 2022-08-24 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-24 04:40:00 to 2022-08-24 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-24 21:20:00 to 2022-08-25 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-25 14:00:00 to 2022-08-26 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-26 06:40:00 to 2022-08-26 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-26 23:20:00 to 2022-08-27 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-27 16:00:00 to 2022-08-28 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-28 08:40:00 to 2022-08-29 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-29 01:20:00 to 2022-08-29 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-29 18:00:00 to 2022-08-30 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-30 10:40:00 to 2022-08-31 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-31 03:20:00 to 2022-08-31 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-08-31 20:00:00 to 2022-09-01 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-01 12:40:00 to 2022-09-02 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-02 05:20:00 to 2022-09-02 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-02 22:00:00 to 2022-09-03 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-03 14:40:00 to 2022-09-04 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-04 07:20:00 to 2022-09-04 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-05 00:00:00 to 2022-09-05 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-05 16:40:00 to 2022-09-06 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-06 09:20:00 to 2022-09-07 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-07 02:00:00 to 2022-09-07 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-07 18:40:00 to 2022-09-08 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-08 11:20:00 to 2022-09-09 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-09 04:00:00 to 2022-09-09 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-09 20:40:00 to 2022-09-10 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-10 13:20:00 to 2022-09-11 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-11 06:00:00 to 2022-09-11 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-11 22:40:00 to 2022-09-12 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-12 15:20:00 to 2022-09-13 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-13 08:00:00 to 2022-09-14 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-14 00:40:00 to 2022-09-14 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-14 17:20:00 to 2022-09-15 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-15 10:00:00 to 2022-09-16 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-16 02:40:00 to 2022-09-16 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-16 19:20:00 to 2022-09-17 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-17 12:00:00 to 2022-09-18 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-18 04:40:00 to 2022-09-18 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-18 21:20:00 to 2022-09-19 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-19 14:00:00 to 2022-09-20 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-20 06:40:00 to 2022-09-20 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-20 23:20:00 to 2022-09-21 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-21 16:00:00 to 2022-09-22 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-22 08:40:00 to 2022-09-23 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-23 01:20:00 to 2022-09-23 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-23 18:00:00 to 2022-09-24 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-24 10:40:00 to 2022-09-25 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-25 03:20:00 to 2022-09-25 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-25 20:00:00 to 2022-09-26 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-26 12:40:00 to 2022-09-27 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-27 05:20:00 to 2022-09-27 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-27 22:00:00 to 2022-09-28 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-28 14:40:00 to 2022-09-29 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-29 07:20:00 to 2022-09-29 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-30 00:00:00 to 2022-09-30 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-09-30 16:40:00 to 2022-10-01 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-01 09:20:00 to 2022-10-02 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-02 02:00:00 to 2022-10-02 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-02 18:40:00 to 2022-10-03 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-03 11:20:00 to 2022-10-04 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-04 04:00:00 to 2022-10-04 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-04 20:40:00 to 2022-10-05 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-05 13:20:00 to 2022-10-06 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-06 06:00:00 to 2022-10-06 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-06 22:40:00 to 2022-10-07 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-07 15:20:00 to 2022-10-08 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-08 08:00:00 to 2022-10-09 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-09 00:40:00 to 2022-10-09 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-09 17:20:00 to 2022-10-10 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-10 10:00:00 to 2022-10-11 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-11 02:40:00 to 2022-10-11 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-11 19:20:00 to 2022-10-12 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-12 12:00:00 to 2022-10-13 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-13 04:40:00 to 2022-10-13 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-13 21:20:00 to 2022-10-14 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-14 14:00:00 to 2022-10-15 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-15 06:40:00 to 2022-10-15 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-15 23:20:00 to 2022-10-16 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-16 16:00:00 to 2022-10-17 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-17 08:40:00 to 2022-10-18 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-18 01:20:00 to 2022-10-18 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-18 18:00:00 to 2022-10-19 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-19 10:40:00 to 2022-10-20 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-20 03:20:00 to 2022-10-20 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-20 20:00:00 to 2022-10-21 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-21 12:40:00 to 2022-10-22 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-22 05:20:00 to 2022-10-22 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-22 22:00:00 to 2022-10-23 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-23 14:40:00 to 2022-10-24 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-24 07:20:00 to 2022-10-24 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-25 00:00:00 to 2022-10-25 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-25 16:40:00 to 2022-10-26 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-26 09:20:00 to 2022-10-27 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-27 02:00:00 to 2022-10-27 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-27 18:40:00 to 2022-10-28 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-28 11:20:00 to 2022-10-29 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-29 04:00:00 to 2022-10-29 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-29 20:40:00 to 2022-10-30 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-30 13:20:00 to 2022-10-31 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-31 06:00:00 to 2022-10-31 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-10-31 22:40:00 to 2022-11-01 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-01 15:20:00 to 2022-11-02 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-02 08:00:00 to 2022-11-03 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-03 00:40:00 to 2022-11-03 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-03 17:20:00 to 2022-11-04 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-04 10:00:00 to 2022-11-05 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-05 02:40:00 to 2022-11-05 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-05 19:20:00 to 2022-11-06 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-06 12:00:00 to 2022-11-07 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-07 04:40:00 to 2022-11-07 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-07 21:20:00 to 2022-11-08 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-08 14:00:00 to 2022-11-09 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-09 06:40:00 to 2022-11-09 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-09 23:20:00 to 2022-11-10 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-10 16:00:00 to 2022-11-11 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-11 08:40:00 to 2022-11-12 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-12 01:20:00 to 2022-11-12 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-12 18:00:00 to 2022-11-13 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-13 10:40:00 to 2022-11-14 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-14 03:20:00 to 2022-11-14 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-14 20:00:00 to 2022-11-15 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-15 12:40:00 to 2022-11-16 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-16 05:20:00 to 2022-11-16 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-16 22:00:00 to 2022-11-17 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-17 14:40:00 to 2022-11-18 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-18 07:20:00 to 2022-11-18 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-19 00:00:00 to 2022-11-19 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-19 16:40:00 to 2022-11-20 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-20 09:20:00 to 2022-11-21 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-21 02:00:00 to 2022-11-21 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-21 18:40:00 to 2022-11-22 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-22 11:20:00 to 2022-11-23 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-23 04:00:00 to 2022-11-23 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-23 20:40:00 to 2022-11-24 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-24 13:20:00 to 2022-11-25 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-25 06:00:00 to 2022-11-25 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-25 22:40:00 to 2022-11-26 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-26 15:20:00 to 2022-11-27 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-27 08:00:00 to 2022-11-28 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-28 00:40:00 to 2022-11-28 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-28 17:20:00 to 2022-11-29 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-29 10:00:00 to 2022-11-30 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-30 02:40:00 to 2022-11-30 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-11-30 19:20:00 to 2022-12-01 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-01 12:00:00 to 2022-12-02 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-02 04:40:00 to 2022-12-02 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-02 21:20:00 to 2022-12-03 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-03 14:00:00 to 2022-12-04 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-04 06:40:00 to 2022-12-04 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-04 23:20:00 to 2022-12-05 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-05 16:00:00 to 2022-12-06 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-06 08:40:00 to 2022-12-07 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-07 01:20:00 to 2022-12-07 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-07 18:00:00 to 2022-12-08 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-08 10:40:00 to 2022-12-09 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-09 03:20:00 to 2022-12-09 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-09 20:00:00 to 2022-12-10 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-10 12:40:00 to 2022-12-11 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-11 05:20:00 to 2022-12-11 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-11 22:00:00 to 2022-12-12 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-12 14:40:00 to 2022-12-13 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-13 07:20:00 to 2022-12-13 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-14 00:00:00 to 2022-12-14 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-14 16:40:00 to 2022-12-15 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-15 09:20:00 to 2022-12-16 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-16 02:00:00 to 2022-12-16 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-16 18:40:00 to 2022-12-17 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-17 11:20:00 to 2022-12-18 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-18 04:00:00 to 2022-12-18 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-18 20:40:00 to 2022-12-19 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-19 13:20:00 to 2022-12-20 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-20 06:00:00 to 2022-12-20 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-20 22:40:00 to 2022-12-21 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-21 15:20:00 to 2022-12-22 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-22 08:00:00 to 2022-12-23 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-23 00:40:00 to 2022-12-23 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-23 17:20:00 to 2022-12-24 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-24 10:00:00 to 2022-12-25 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-25 02:40:00 to 2022-12-25 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-25 19:20:00 to 2022-12-26 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-26 12:00:00 to 2022-12-27 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-27 04:40:00 to 2022-12-27 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-27 21:20:00 to 2022-12-28 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-28 14:00:00 to 2022-12-29 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-29 06:40:00 to 2022-12-29 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-29 23:20:00 to 2022-12-30 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-30 16:00:00 to 2022-12-31 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2022-12-31 08:40:00 to 2023-01-01 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-01 01:20:00 to 2023-01-01 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-01 18:00:00 to 2023-01-02 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-02 10:40:00 to 2023-01-03 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-03 03:20:00 to 2023-01-03 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-03 20:00:00 to 2023-01-04 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-04 12:40:00 to 2023-01-05 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-05 05:20:00 to 2023-01-05 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-05 22:00:00 to 2023-01-06 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-06 14:40:00 to 2023-01-07 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-07 07:20:00 to 2023-01-07 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-08 00:00:00 to 2023-01-08 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-08 16:40:00 to 2023-01-09 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-09 09:20:00 to 2023-01-10 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-01-10 02:00:00 to 2023-01-10 18:39:00
# ...
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-06-29 06:40:00 to 2023-06-29 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-06-29 23:20:00 to 2023-06-30 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-06-30 16:00:00 to 2023-07-01 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-01 08:40:00 to 2023-07-02 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-02 01:20:00 to 2023-07-02 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-02 18:00:00 to 2023-07-03 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-03 10:40:00 to 2023-07-04 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-04 03:20:00 to 2023-07-04 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-04 20:00:00 to 2023-07-05 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-05 12:40:00 to 2023-07-06 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-06 05:20:00 to 2023-07-06 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-06 22:00:00 to 2023-07-07 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-07 14:40:00 to 2023-07-08 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-08 07:20:00 to 2023-07-08 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-09 00:00:00 to 2023-07-09 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-09 16:40:00 to 2023-07-10 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-10 09:20:00 to 2023-07-11 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-11 02:00:00 to 2023-07-11 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-11 18:40:00 to 2023-07-12 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-12 11:20:00 to 2023-07-13 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-13 04:00:00 to 2023-07-13 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-13 20:40:00 to 2023-07-14 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-14 13:20:00 to 2023-07-15 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-15 06:00:00 to 2023-07-15 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-15 22:40:00 to 2023-07-16 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-16 15:20:00 to 2023-07-17 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-17 08:00:00 to 2023-07-18 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-18 00:40:00 to 2023-07-18 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-18 17:20:00 to 2023-07-19 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-19 10:00:00 to 2023-07-20 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-20 02:40:00 to 2023-07-20 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-20 19:20:00 to 2023-07-21 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-21 12:00:00 to 2023-07-22 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-22 04:40:00 to 2023-07-22 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-22 21:20:00 to 2023-07-23 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-23 14:00:00 to 2023-07-24 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-24 06:40:00 to 2023-07-24 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-24 23:20:00 to 2023-07-25 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-25 16:00:00 to 2023-07-26 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-26 08:40:00 to 2023-07-27 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-27 01:20:00 to 2023-07-27 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-27 18:00:00 to 2023-07-28 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-28 10:40:00 to 2023-07-29 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-29 03:20:00 to 2023-07-29 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-29 20:00:00 to 2023-07-30 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-30 12:40:00 to 2023-07-31 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-31 05:20:00 to 2023-07-31 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-07-31 22:00:00 to 2023-08-01 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-01 14:40:00 to 2023-08-02 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-02 07:20:00 to 2023-08-02 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-03 00:00:00 to 2023-08-03 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-03 16:40:00 to 2023-08-04 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-04 09:20:00 to 2023-08-05 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-05 02:00:00 to 2023-08-05 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-05 18:40:00 to 2023-08-06 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-06 11:20:00 to 2023-08-07 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-07 04:00:00 to 2023-08-07 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-07 20:40:00 to 2023-08-08 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-08 13:20:00 to 2023-08-09 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-09 06:00:00 to 2023-08-09 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-09 22:40:00 to 2023-08-10 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-10 15:20:00 to 2023-08-11 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-11 08:00:00 to 2023-08-12 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-12 00:40:00 to 2023-08-12 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-12 17:20:00 to 2023-08-13 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-13 10:00:00 to 2023-08-14 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-14 02:40:00 to 2023-08-14 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-14 19:20:00 to 2023-08-15 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-15 12:00:00 to 2023-08-16 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-16 04:40:00 to 2023-08-16 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-16 21:20:00 to 2023-08-17 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-17 14:00:00 to 2023-08-18 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-18 06:40:00 to 2023-08-18 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-18 23:20:00 to 2023-08-19 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-19 16:00:00 to 2023-08-20 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-20 08:40:00 to 2023-08-21 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-21 01:20:00 to 2023-08-21 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-21 18:00:00 to 2023-08-22 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-22 10:40:00 to 2023-08-23 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-23 03:20:00 to 2023-08-23 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-23 20:00:00 to 2023-08-24 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-24 12:40:00 to 2023-08-25 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-25 05:20:00 to 2023-08-25 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-25 22:00:00 to 2023-08-26 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-26 14:40:00 to 2023-08-27 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-27 07:20:00 to 2023-08-27 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-28 00:00:00 to 2023-08-28 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-28 16:40:00 to 2023-08-29 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-29 09:20:00 to 2023-08-30 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-30 02:00:00 to 2023-08-30 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-30 18:40:00 to 2023-08-31 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-08-31 11:20:00 to 2023-09-01 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-01 04:00:00 to 2023-09-01 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-01 20:40:00 to 2023-09-02 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-02 13:20:00 to 2023-09-03 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-03 06:00:00 to 2023-09-03 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-03 22:40:00 to 2023-09-04 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-04 15:20:00 to 2023-09-05 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-05 08:00:00 to 2023-09-06 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-06 00:40:00 to 2023-09-06 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-06 17:20:00 to 2023-09-07 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-07 10:00:00 to 2023-09-08 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-08 02:40:00 to 2023-09-08 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-08 19:20:00 to 2023-09-09 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-09 12:00:00 to 2023-09-10 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-10 04:40:00 to 2023-09-10 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-10 21:20:00 to 2023-09-11 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-11 14:00:00 to 2023-09-12 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-12 06:40:00 to 2023-09-12 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-12 23:20:00 to 2023-09-13 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-13 16:00:00 to 2023-09-14 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-14 08:40:00 to 2023-09-15 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-15 01:20:00 to 2023-09-15 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-15 18:00:00 to 2023-09-16 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-16 10:40:00 to 2023-09-17 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-17 03:20:00 to 2023-09-17 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-17 20:00:00 to 2023-09-18 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-18 12:40:00 to 2023-09-19 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-19 05:20:00 to 2023-09-19 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-19 22:00:00 to 2023-09-20 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-20 14:40:00 to 2023-09-21 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-21 07:20:00 to 2023-09-21 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-22 00:00:00 to 2023-09-22 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-22 16:40:00 to 2023-09-23 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-23 09:20:00 to 2023-09-24 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-24 02:00:00 to 2023-09-24 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-24 18:40:00 to 2023-09-25 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-25 11:20:00 to 2023-09-26 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-26 04:00:00 to 2023-09-26 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-26 20:40:00 to 2023-09-27 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-27 13:20:00 to 2023-09-28 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-28 06:00:00 to 2023-09-28 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-28 22:40:00 to 2023-09-29 15:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-29 15:20:00 to 2023-09-30 07:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-09-30 08:00:00 to 2023-10-01 00:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-01 00:40:00 to 2023-10-01 17:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-01 17:20:00 to 2023-10-02 09:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-02 10:00:00 to 2023-10-03 02:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-03 02:40:00 to 2023-10-03 19:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-03 19:20:00 to 2023-10-04 11:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-04 12:00:00 to 2023-10-05 04:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-05 04:40:00 to 2023-10-05 21:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-05 21:20:00 to 2023-10-06 13:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-06 14:00:00 to 2023-10-07 06:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-07 06:40:00 to 2023-10-07 23:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-07 23:20:00 to 2023-10-08 15:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-08 16:00:00 to 2023-10-09 08:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-09 08:40:00 to 2023-10-10 01:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-10 01:20:00 to 2023-10-10 17:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-10 18:00:00 to 2023-10-11 10:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-11 10:40:00 to 2023-10-12 03:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-12 03:20:00 to 2023-10-12 19:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-12 20:00:00 to 2023-10-13 12:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-13 12:40:00 to 2023-10-14 05:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-14 05:20:00 to 2023-10-14 21:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-14 22:00:00 to 2023-10-15 14:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-15 14:40:00 to 2023-10-16 07:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-16 07:20:00 to 2023-10-16 23:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-17 00:00:00 to 2023-10-17 16:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-17 16:40:00 to 2023-10-18 09:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-18 09:20:00 to 2023-10-19 01:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-19 02:00:00 to 2023-10-19 18:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-19 18:40:00 to 2023-10-20 11:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-20 11:20:00 to 2023-10-21 03:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-21 04:00:00 to 2023-10-21 20:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-21 20:40:00 to 2023-10-22 13:19:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-22 13:20:00 to 2023-10-23 05:59:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-23 06:00:00 to 2023-10-23 22:39:00
# BINANCE BTCUSDT : Collected 1000 initial data from 2023-10-23 22:40:00 to 2023-10-24 15:19:00
# BINANCE BTCUSDT : Collected 521 initial data from 2023-10-24 15:20:00 to 2023-10-25 00:00:00

# %%
def get_binance_data(api_key, pair, countdown='open', interval='1h', start='01 Jan 2022', end=None):
  client = Client(api_key=api_key)
  intervals = {
      '15m': Client.KLINE_INTERVAL_15MINUTE,
      '1h':  Client.KLINE_INTERVAL_1HOUR,      
      '4h':  Client.KLINE_INTERVAL_4HOUR,
      '1d':  Client.KLINE_INTERVAL_1DAY
  }
  interval = intervals.get(interval, '1h')
  print(f'Historical interval {interval}')
  klines = client.get_historical_klines(symbol=pair, interval=interval, start_str=start, end_str=end)
  data = pd.DataFrame(klines)
  data.columns = ['open_time','open', 'high', 'low', 'close', 'volume','close_time', 'qav','num_trades','taker_base_vol','taker_quote_vol', 'ignore']
  data.index = [pd.to_datetime(x, unit='ms').strftime('%Y-%m-%d %H:%M:%S') for x in data.open_time]
  #usecols=['open', 'high', 'low', 'close', 'volume']
  #data = data[usecols]
  data = data.astype('float')
  return data



symbol = 'BTCUSDT'
df = get_binance_data(api_key, symbol)
df.to_csv('btc_1h_data.csv')
# Out:
# Historical interval 1h

# %%
df
# Out:
#                         open_time      open      high       low     close  \
# 2022-01-01 00:00:00  1.640995e+12  46216.93  46731.39  46208.37  46656.13
# 2022-01-01 01:00:00  1.640999e+12  46656.14  46949.99  46574.06  46778.14
# 2022-01-01 02:00:00  1.641002e+12  46778.14  46928.94  46721.96  46811.77
# 2022-01-01 03:00:00  1.641006e+12  46811.77  46916.63  46760.12  46813.20
# 2022-01-01 04:00:00  1.641010e+12  46813.21  46887.33  46591.23  46711.05
# ...                           ...       ...       ...       ...       ...
# 2023-10-26 07:00:00  1.698304e+12  34615.16  34784.61  34551.50  34647.34
# 2023-10-26 08:00:00  1.698307e+12  34647.35  34745.86  34499.00  34520.85
# 2023-10-26 09:00:00  1.698311e+12  34520.86  34585.77  34405.27  34429.23
# 2023-10-26 10:00:00  1.698314e+12  34429.23  34450.81  34100.64  34277.56
# 2023-10-26 11:00:00  1.698318e+12  34277.57  34325.86  34200.44  34212.09
#
#                          volume    close_time           qav  num_trades  \
# 2022-01-01 00:00:00  1503.33095  1.640999e+12  6.987999e+07     38608.0
# 2022-01-01 01:00:00   943.81539  1.641002e+12  4.412715e+07     31872.0
# 2022-01-01 02:00:00   485.16860  1.641006e+12  2.272067e+07     24364.0
# 2022-01-01 03:00:00   562.88971  1.641010e+12  2.636326e+07     19882.0
# 2022-01-01 04:00:00   861.88389  1.641013e+12  4.027204e+07     23357.0
# ...                         ...           ...           ...         ...
# 2023-10-26 07:00:00  2098.65673  1.698307e+12  7.281145e+07     69793.0
# 2023-10-26 08:00:00  1940.94276  1.698311e+12  6.713873e+07     62795.0
# 2023-10-26 09:00:00  1622.90871  1.698314e+12  5.594760e+07     53063.0
# 2023-10-26 10:00:00  2720.37183  1.698318e+12  9.335226e+07     86913.0
# 2023-10-26 11:00:00   607.29323  1.698322e+12  2.081574e+07     20933.0
#
#                      taker_base_vol  taker_quote_vol  ignore
# 2022-01-01 00:00:00       806.06536     3.746216e+07     0.0
# 2022-01-01 01:00:00       491.18067     2.296327e+07     0.0
# 2022-01-01 02:00:00       206.35113     9.662607e+06     0.0
# 2022-01-01 03:00:00       248.28212     1.162938e+07     0.0
# 2022-01-01 04:00:00       397.53563     1.857540e+07     0.0
# ...                             ...              ...     ...
# 2023-10-26 07:00:00      1198.96420     4.159797e+07     0.0
# 2023-10-26 08:00:00       986.15616     3.411179e+07     0.0
# 2023-10-26 09:00:00       783.94296     2.702419e+07     0.0
# 2023-10-26 10:00:00      1192.83656     4.092673e+07     0.0
# 2023-10-26 11:00:00       275.94754     9.458882e+06     0.0
#
# [15923 rows x 12 columns]
